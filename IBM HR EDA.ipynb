# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
outlier_col=df.select_dtypes(include=np.number)

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=outlier_col)
plt.xticks(rotation=45)
plt.show()

# %%
total_before = 0
for col in outlier_col:
    Q1 = a[col].quantile(0.25)
    Q3 = a[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    count = ((a[col] < lower) | (a[col] > upper)).sum()
    total_before += count
total_before
# Out:
# np.int64(1024)

# %%
for col in outlier_col:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    df[col] = np.where(df[col] < lower, lower, df[col])
    df[col] = np.where(df[col] > upper, upper, df[col])

# %%
total_after = 0
for col in outlier_col:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    count = ((df[col] < lower) | (df[col] > upper)).sum()
    total_after += count
total_after
# Out:
# np.int64(0)

# %%
outlier_col=df.select_dtypes(include=np.number)
plt.figure(figsize=(15,10))
sns.boxplot(data=outlier_col)
plt.xticks(rotation=45)
plt.show()

# %%
total_emp = len(df)
total_emp
# Out:
# 1470

# %%
attrition_count = (df['Attrition'] == 'Yes').sum()
attrition_count
# Out:
# np.int64(237)

# %%
attrition_rate = round(attrition_count / total_emp * 100, 2)
attrition_rate
# Out:
# np.float64(16.12)

# %%
a=df["Attrition"].value_counts()

# %%
b=df[df["Attrition"]=="Yes"]["JobRole"].value_counts()

# %%
bins=[18, 25, 35, 45, 55, 65]
labels=["18-25", "26-35", "36-45", "46-55", "56-65"]
df["Age Group"] = pd.cut(df["Age"],bins=bins,labels=labels)
c=df["Age Group"].value_counts()

# %%
d=df.groupby("Department")["MonthlyIncome"].mean()

# %%
e=df.groupby("Age Group")["MonthlyIncome"].count()
# Out:
# /tmp/ipykernel_1295/4223971801.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   e=df.groupby("Age Group")["MonthlyIncome"].count()

# %%
bins=[0, 5000, 10000, 15000, 20000]
labels=["Low", "Medium", "High", "Very High"]
df["Income Group"] = pd.cut(df["MonthlyIncome"],bins=bins,labels=labels)
f=df.groupby("Income Group")["MonthlyIncome"].count()
# Out:
# /tmp/ipykernel_1295/3015042245.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   f=df.groupby("Income Group")["MonthlyIncome"].count()

# %%
fig, ax = plt.subplots(2, 3, figsize=(20,10))
ax[0,0].pie(a, labels=a.index, autopct="%1.2f%%")
ax[0,1].bar(b.index, b.values)
ax[0,1].set_xticklabels(b.index, rotation=45, ha='right')
ax[0,2].bar(c.index, c.values)
ax[1,0].bar(d.index, d.values)
ax[1,1].bar(e.index, e.values)
ax[1,2].bar(f.index, f.values)
fig.suptitle("IBM HR EDA DASHBOARD")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1295/1783571678.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0,1].set_xticklabels(b.index, rotation=45, ha='right')

# %% [markdown]
# # Data Story Telling
#
#
# 1.   Total number of employees in the company are 1470
# 2.   The company has an attrition rate of 16.12%
# 1.   Most attrition cases are from Laboratory Technicians and Sales Executives.
# 2.   Most employees belong to the 26–35 age group.
# 1.   Employees in the Sales department have the highest average income.
# 2.   The majority of employees are in the Low and Medium income groups.
# 1.   Young and mid-career employees make up most of the organization.
# 2.   Employee count decreases as income level increases.
# 1.   Very High income employees form the smallest employee group.
